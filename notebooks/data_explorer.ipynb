# %%
import os, sys
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

sys.path.append('../')

from src.dataset import DataSet

root_path = os.path.dirname(os.getcwd())

# %%
dataset = DataSet(machine='exalearn')
#dataset.spec_train += .5

# %%
N = 100

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(16,4))
for i in range(N):
    spec, label, n = dataset[i]
    ax.plot(spec)
plt.show()

# %%
spec.shape
# Out:
# (1696, 1)

# %%
import torch

# %%
torch.randn((10,10,10)).size()[0]
# Out:
# 10
